# %%
from skimage.exposure import rescale_intensity

# Ensure both images are in the correct range for conversion to 8-bit
image1 = rescale_intensity(image1, out_range=(0, 255)).astype(np.uint8)
image2 = rescale_intensity(image2, out_range=(0, 255)).astype(np.uint8)

# Recalculate Shannon Entropy for both images
entropy1 = calculate_shannon_entropy(image1)
entropy2 = calculate_shannon_entropy(image2)

entropy1, entropy2
# Out:
# (7.454524467844189, -0.0)

# %%
import matplotlib.pyplot as plt

# Plot the two images side by side
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(image1, cmap='gray')
axes[0].set_title("Image 1: Complex")
axes[0].axis('off')

axes[1].imshow(image2, cmap='gray')
axes[1].set_title("Image 2: Uniform")
axes[1].axis('off')

plt.tight_layout()
plt.show()
