# %%
#!/usr/bin/env python
# coding: utf-8
#NOTE: use paimg9 env

import sys
import os
import numpy as np
import openslide
from fastai.vision.all import *
matplotlib.use('Agg')
import pandas as pd
import warnings
sys.path.insert(0, '../Utils/')
from Preprocessing import preprocess_mutation_data, preprocess_site_data, get_tile_representation, get_tile_representation_tma
from Utils import generate_deepzoom_tiles
from Utils import create_dir_if_not_exists
warnings.filterwarnings("ignore")

import ResNet as ResNet
import time
import PIL 
import timm

# %%
############################################################################################################
#USER INPUT 
############################################################################################################
pixel_overlap = 0      # specify the level of pixel overlap in your saved images
save_image_size = 250
limit_bounds = True     # this is weird, dont change it
cohort_name = "TAN_TMA_Cores"  #TAN_TMA_Cores
feature_extraction_method = 'uni1' #retccl, uni1, uni2
folder_name = cohort_name + "/" + "IMSIZE" + str(save_image_size) + "_OL" + str(pixel_overlap) + "/" 


if feature_extraction_method == 'retccl':
    resize_transform = False
else:
    resize_transform = True
############################################################################################################
#DIR
############################################################################################################
proj_dir = '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/'
model_path = proj_dir + 'models/feature_extraction_models/' + feature_extraction_method + '/'

wsi_location_opx = proj_dir + '/data/OPX/'
wsi_location_tan = proj_dir + 'data/TAN_TMA_Cores/'
wsi_location_ccola = proj_dir + '/data/CCola/all_slides/'
tile_info_path = proj_dir + 'intermediate_data/3_updated_tile_info/'+ folder_name

out_location = proj_dir + 'intermediate_data/4_tile_feature/'+ folder_name
create_dir_if_not_exists(out_location)

##################
#Select GPU
##################
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/' already exists.

# %%
############################################################################################################
#Select IDS
############################################################################################################
#Get IDs that are in FT train or already processed to exclude 
fine_tune_ids_df = pd.read_csv(proj_dir + 'intermediate_data/0_cd_finetune/cancer_detection_training/all_tumor_fraction_info.csv')
ft_train_ids = list(fine_tune_ids_df.loc[fine_tune_ids_df['Train_OR_Test'] == 'Train','sample_id']) #24, 7 from OPX, 17 from ccola
toexclude_ids = ft_train_ids 

#All available IDs
opx_ids = [x.replace('.tif','') for x in os.listdir(wsi_location_opx)] #217
ccola_ids = [x.replace('.svs','') for x in os.listdir(wsi_location_ccola) if '(2017-0133)' in x] #234
tan_ids =  [x.replace('.tif','') for x in os.listdir(wsi_location_tan)] #677

if cohort_name == "OPX":
    all_ids = opx_ids
elif cohort_name == "ccola":
    all_ids = ccola_ids
elif cohort_name == "TAN_TMA_Cores":
    all_ids = tan_ids
elif cohort_name == "all":
    all_ids = opx_ids + ccola_ids + tan_ids

#Exclude ids in ft_train or processed
selected_ids = [x for x in all_ids if x not in toexclude_ids] #209 for 
selected_ids.sort()

# %%
################################################
#Load tile info 
################################################
tile_info_df = pd.read_csv(tile_info_path + "all_tile_info.csv")

# %%
############################################################################################################
# Load Pretrained representation model
############################################################################################################
if feature_extraction_method == 'retccl':
    model = ResNet.resnet50(num_classes=128,mlp=False, two_branch=False, normlinear=True)
    pretext_model = torch.load(model_path + 'best_ckpt.pth',map_location=torch.device(device))
    model.fc = nn.Identity()
    model.load_state_dict(pretext_model, strict=True)
elif feature_extraction_method == 'uni1':
    model = timm.create_model("vit_large_patch16_224",img_size = 224, patch_size=16, init_values=1e-5, num_classes=0, dynamic_img_size=True) # img_size=224, patch_size=16, 
    model.load_state_dict(torch.load(os.path.join(model_path, "vit_large_patch16_224.dinov2.uni_mass100k.bin"), map_location="cpu"), strict=True)
elif feature_extraction_method == 'uni2':
    timm_kwargs = {
       'model_name': 'vit_giant_patch14_224',
       'img_size': 224, 
       'patch_size': 14, 
       'depth': 24,
       'num_heads': 24,
       'init_values': 1e-5, 
       'embed_dim': 1536,
       'mlp_ratio': 2.66667*2,
       'num_classes': 0, 
       'no_embed_class': True,
       'mlp_layer': timm.layers.SwiGLUPacked, 
       'act_layer': torch.nn.SiLU, 
       'reg_tokens': 8, 
       'dynamic_img_size': True
      }
    model = timm.create_model(**timm_kwargs)
    model.load_state_dict(torch.load(os.path.join(model_path, "uni2-h.bin"), map_location="cpu"), strict=True)

# %%
############################################################################################################
#For each patient tile, get representation
############################################################################################################
ct = 0 
for cur_id in selected_ids:
    print(cur_id)

    if ct % 10 == 0: print(ct)

    if 'OPX' in cur_id:
        _file = wsi_location_opx + cur_id + ".tif"
    elif '(2017-0133)' in cur_id:
        _file = wsi_location_ccola + cur_id + '.svs'
    elif 'TMA' in cur_id:
        _file = wsi_location_tan + cur_id + '.tif'

    
    save_name = str(Path(os.path.basename(_file)).with_suffix(''))
    
    if cohort_name == "OPX":
        #Load slide
        oslide = openslide.OpenSlide(_file)

        #Get tile info
        cur_tile_info_df = tile_info_df.loc[tile_info_df['SAMPLE_ID'] == cur_id]
        
        #Generate tiles
        tiles, tile_lvls, physSize, base_mag = generate_deepzoom_tiles(oslide,save_image_size, pixel_overlap, limit_bounds)        
        
        #Grab tile 
        tile_img = get_tile_representation(cur_tile_info_df, tiles, tile_lvls, model, resize_transform)
        

        
    elif cohort_name == "TAN_TMA_Cores":      
        #Load slide
        tma = PIL.Image.open(_file)
        
        #Get tile info
        cur_tile_info_df = tile_info_df.loc[tile_info_df['SAMPLE_ID'] == cur_id]
        
        #Grab tile 
        tile_img = get_tile_representation_tma(cur_tile_info_df,tma, model, resize_transform)



    
    #Get feature
    start_time = time.time()
    feature_list = [tile_img[i][1] for i in range(cur_tile_info_df.shape[0])]
    print("--- %s seconds ---" % (time.time() - start_time))
    feature_df = np.concatenate(feature_list)
    feature_df = pd.DataFrame(feature_df)
                
    
    
    save_location = out_location + cur_id + '/features/'
    create_dir_if_not_exists(save_location)
    save_name = save_location + 'features_alltiles_' + feature_extraction_method + '.h5'
    feature_df.to_hdf(save_name, key='feature', mode='w')
    cur_tile_info_df.to_hdf(save_name, key='tile_info', mode='a')

    ct += 1
# Out:
# TMA97A-1-11
# 0
# --- 3.3711657524108887 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-11/features/' already exists.
# TMA97A-1-12
# --- 3.1593401432037354 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-12/features/' already exists.
# TMA97A-1-13
# --- 4.9950339794158936 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-13/features/' already exists.
# TMA97A-1-2
# --- 13.836332321166992 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-2/features/' already exists.
# TMA97A-1-3
# --- 11.709094047546387 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-3/features/' already exists.
# TMA97A-1-6
# --- 8.470728397369385 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-6/features/' already exists.
# TMA97A-1-9
# --- 26.365551471710205 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-1-9/features/' already exists.
# TMA97A-2-1
# --- 20.168047189712524 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-2-1/features/' already exists.
# TMA97A-2-2
# --- 1.4832942485809326 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-2-2/features/' already exists.
# TMA97A-2-3
# --- 26.980401754379272 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-2-3/features/' already exists.
# TMA97A-2-4
# 10
# --- 22.972376108169556 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-2-4/features/' already exists.
# TMA97A-2-5
# --- 24.711549997329712 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-2-5/features/' already exists.
# TMA97A-3-1
# --- 11.674105167388916 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-1/features/' already exists.
# TMA97A-3-10
# --- 22.578737497329712 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-10/features/' already exists.
# TMA97A-3-11
# --- 24.537561893463135 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-11/features/' already exists.
# TMA97A-3-12
# --- 32.123607873916626 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-12/features/' already exists.
# TMA97A-3-13
# --- 31.313637733459473 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-13/features/' already exists.
# TMA97A-3-2
# --- 7.369967460632324 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-2/features/' already exists.
# TMA97A-3-5
# --- 10.462402820587158 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-5/features/' already exists.
# TMA97A-3-6
# --- 22.605891704559326 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-6/features/' already exists.
# TMA97A-3-9
# 20
# --- 15.736378192901611 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-3-9/features/' already exists.
# TMA97A-4-1
# --- 28.28800320625305 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-1/features/' already exists.
# TMA97A-4-10
# --- 25.55058526992798 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-10/features/' already exists.
# TMA97A-4-11
# --- 25.51853346824646 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-11/features/' already exists.
# TMA97A-4-12
# --- 18.431954860687256 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-12/features/' already exists.
# TMA97A-4-2
# --- 33.18713450431824 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-2/features/' already exists.
# TMA97A-4-3
# --- 22.78888440132141 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-3/features/' already exists.
# TMA97A-4-4
# --- 31.891953945159912 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-4/features/' already exists.
# TMA97A-4-5
# --- 38.437281370162964 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-5/features/' already exists.
# TMA97A-4-6
# --- 37.35890436172485 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-6/features/' already exists.
# TMA97A-4-7
# 30
# --- 35.027398109436035 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-7/features/' already exists.
# TMA97A-4-8
# --- 35.998714208602905 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-8/features/' already exists.
# TMA97A-4-9
# --- 36.07969331741333 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-4-9/features/' already exists.
# TMA97A-5-1
# --- 33.172791719436646 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-1/features/' already exists.
# TMA97A-5-10
# --- 24.447527170181274 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-10/features/' already exists.
# TMA97A-5-11
# --- 26.223363399505615 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-11/features/' already exists.
# TMA97A-5-12
# --- 26.222025394439697 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-12/features/' already exists.
# TMA97A-5-13
# --- 27.067906141281128 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-13/features/' already exists.
# TMA97A-5-2
# --- 33.24534583091736 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-2/features/' already exists.
# TMA97A-5-3
# --- 12.482613325119019 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-3/features/' already exists.
# TMA97A-5-5
# 40
# --- 29.209962606430054 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-5/features/' already exists.
# TMA97A-5-6
# --- 29.0306236743927 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-6/features/' already exists.
# TMA97A-5-7
# --- 10.445819854736328 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-7/features/' already exists.
# TMA97A-5-8
# --- 30.82969832420349 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-5-8/features/' already exists.
# TMA97A-6-1
# --- 12.921188831329346 seconds ---
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/4_tile_feature/TAN_TMA_Cores/IMSIZE250_OL0/TMA97A-6-1/features/' already exists.
# TMA97A-6-10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 50
#      48 #Get feature
#      49 start_time = time.time()
# ---> 50 feature_list = [tile_img[i][1] for i in range(cur_tile_info_df.shape[0])]
#      51 print("--- %s seconds ---" % (time.time() - start_time))
#      52 feature_df = np.concatenate(feature_list)
#
# Cell In[6], line 50, in <listcomp>(.0)
#      48 #Get feature
#      49 start_time = time.time()
# ---> 50 feature_list = [tile_img[i][1] for i in range(cur_tile_info_df.shape[0])]
#      51 print("--- %s seconds ---" % (time.time() - start_time))
#      52 feature_df = np.concatenate(feature_list)
#
# File /fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/code_s/cancer_detection_final/../Utils/Preprocessing.py:137, in __getitem__(self, idx)
#     135 if resize == False:
#     136     tile_pull_trns = self.transform(tile_pull)
# --> 137 else:
#     138     tile_pull_trns = self.transform_resize(tile_pull)
#     139 tile_pull_trns = tile_pull_trns.unsqueeze(0)  # Adds a dimension at the 0th index
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/timm/models/vision_transformer.py:849, in VisionTransformer.forward(self, x)
#     848 def forward(self, x: torch.Tensor) -> torch.Tensor:
# --> 849     x = self.forward_features(x)
#     850     x = self.forward_head(x)
#     851     return x
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/timm/models/vision_transformer.py:830, in VisionTransformer.forward_features(self, x)
#     828     x = checkpoint_seq(self.blocks, x)
#     829 else:
# --> 830     x = self.blocks(x)
#     831 x = self.norm(x)
#     832 return x
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/timm/models/vision_transformer.py:170, in Block.forward(self, x)
#     168 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     169     x = x + self.drop_path1(self.ls1(self.attn(self.norm1(x))))
# --> 170     x = x + self.drop_path2(self.ls2(self.mlp(self.norm2(x))))
#     171     return x
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/timm/layers/mlp.py:44, in Mlp.forward(self, x)
#      43 def forward(self, x):
# ---> 44     x = self.fc1(x)
#      45     x = self.act(x)
#      46     x = self.drop1(x)
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/paimg9/lib/python3.8/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
