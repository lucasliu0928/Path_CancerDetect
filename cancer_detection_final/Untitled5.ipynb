# %%
import torch
import torch.nn as nn
# NLP Example
batch, sentence_length, embedding_dim = 1, 100, 128
embedding = torch.randn(batch, sentence_length, embedding_dim)
layer_norm = nn.LayerNorm(embedding_dim)
# Activate module
normed = layer_norm(embedding)

# %%
test_pred_prob
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 test_pred_prob
#
# NameError: name 'test_pred_prob' is not defined

# %%
normed[0,0,:]
# Out:
# tensor([-1.9497, -1.0350,  0.4580,  0.2698, -1.0712, -2.0802, -0.2680,  0.4173,
#          0.1118, -1.6641,  1.4379,  1.0772,  0.6907, -0.4267,  1.5765,  0.0530,
#         -0.9787, -0.2919, -0.6610,  0.1924, -0.5548,  0.5377,  0.5763,  0.4697,
#          0.2864, -1.4983,  0.4525, -0.1572, -1.1186, -0.2669,  1.8131,  1.8548,
#         -0.3610,  0.2164, -0.1720,  1.4847, -0.1386, -0.0155, -2.4824, -0.0766,
#          0.6671, -0.5428, -0.6560,  1.9401, -0.7854,  1.6156,  0.3993, -0.7656,
#         -0.0081, -0.8073, -1.2789, -0.0388,  0.6911, -0.2071,  0.5678, -0.7305,
#          0.3300, -0.6218,  0.9802, -1.5366, -0.0926, -0.8692, -0.2307, -1.0060,
#          0.1131,  0.7093, -1.3505, -1.9897,  0.1833,  0.6108, -0.7853,  1.8943,
#          0.1472,  1.4439,  1.2328, -0.0736,  1.3814, -0.3639, -1.0525,  0.7934,
#         -0.2551, -0.6600, -0.9573,  0.7942, -0.1021,  0.9613,  0.9331,  0.4752,
#          1.7102,  0.8615, -1.8523,  0.1432, -0.1905,  0.6414,  1.5490,  0.5339,
# ...
