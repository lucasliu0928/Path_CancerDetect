# %%
total_n = 15210
n1 = 11  #trt grp #case
n2 = 185 #placebo #case
n3 = total_n - n1 # trt grp not case
n4 = total_n - n2  #placebo not case
print(n1)
print(n2)
print(n3)
print(n4)
print(n1+n2)
# Out:
# 11
# 185
# 15199
# 15025
# 196

# %%
(196/(total_n*2))*total_n
# Out:
# 98.0

# %%
en1 = total_n * (196/(n1+n2+n3+n4))
en2 = total_n * (196/(n1+n2+n3+n4))
en3 = total_n - en1
en4 = total_n - en2
print(en1)
print(en2)
print(en3)
print(en4)
# Out:
# 98.0
# 98.0
# 15112.0
# 15112.0

# %%
obs1 = ((n1-en1)**2)/en1
obs2 = ((n3-en3)**2)/en3
obs3 = ((n2-en2)**2)/en2
obs4 = ((n4-en4)**2)/en4
print(obs1)
print(obs2)
print(obs3)
print(obs4)
# Out:
# 77.23469387755102
# 0.5008602435150874
# 77.23469387755102
# 0.5008602435150874

# %%
final_obs = obs1 + obs2 + obs3 + obs4
print(final_obs)
# Out:
# 155.47110824213223
