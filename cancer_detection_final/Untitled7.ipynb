# %%
import torch
import pandas as pd

# %%
#Check old and new retccl feature
proj_dir = "/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/"
old_path = proj_dir + "TODELETE_cancer_prediction_results110224/IMSIZE250_OL100/OPX_001/features/"
new_path = proj_dir + "/4_tile_feature/OPX/IMSIZE250_OL100/OPX_001/features/"
feature_df_old = pd.read_hdf(old_path + 'features_alltiles_retccl.h5', key='feature')
feature_df_new = pd.read_hdf(new_path + 'features_alltiles_retccl.h5', key='feature')
