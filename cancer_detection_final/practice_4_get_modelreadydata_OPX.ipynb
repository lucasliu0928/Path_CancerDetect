# %%
#NOTE: use paimg9 env
import sys
import os
import numpy as np
import openslide
import pandas as pd
import warnings
import torch
import torch.nn as nn

sys.path.insert(0, '../Utils/')
from Utils import create_dir_if_not_exists, count_label, set_seed
from train_utils import ModelReadyData_diffdim, get_feature_label_array_dynamic
warnings.filterwarnings("ignore")

# %%
####################################
######      USERINPUT       ########
####################################
SELECTED_LABEL = ["AR","MMR (MSH2, MSH6, PMS2, MLH1, MSH3, MLH3, EPCAM)2","PTEN","RB1","TP53","TMB_HIGHorINTERMEDITATE","MSI_POS"]
TUMOR_FRAC_THRES = 0.9
pixel_overlap = 0    
save_image_size = 250
cohort_name = "OPX"  
feature_extraction_method = 'uni2' #retccl, uni1
folder_name = cohort_name + "/" + "IMSIZE" + str(save_image_size) + "_OL" + str(pixel_overlap) + "/" 

if feature_extraction_method == 'retccl':
    SELECTED_FEATURE = [str(i) for i in range(0,2048)] + ['TUMOR_PIXEL_PERC'] #If retccl 2048, if uni 1024
elif feature_extraction_method == 'uni1': 
    SELECTED_FEATURE = [str(i) for i in range(0,1024)] + ['TUMOR_PIXEL_PERC'] #If retccl 2048, if uni 1024
elif feature_extraction_method == 'uni2':
    SELECTED_FEATURE = [str(i) for i in range(0,1536)] + ['TUMOR_PIXEL_PERC'] #If retccl 2048, if uni 1024

##################
###### DIR  ######
##################
proj_dir = '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/'
feature_path = proj_dir + 'intermediate_data/4_tile_feature/' + folder_name
tumor_info_path =  proj_dir + 'intermediate_data/2_cancer_detection/' + folder_name

################################################
#Create output dir
################################################
outdir =  os.path.join(proj_dir + 'intermediate_data/5_model_ready_data', 
                       folder_name, 
                       'feature_' + feature_extraction_method, 
                       'TFT' + str(TUMOR_FRAC_THRES))
create_dir_if_not_exists(outdir)

##################
#Select GPU
##################
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
set_seed(0)
# Out:
# Directory '/fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/intermediate_data/5_model_ready_data/TAN_TMA_Cores/IMSIZE250_OL0/feature_uni2/TFT0.9' already exists.
# cuda:0

# %%
############################################################################################################
#Select OPX IDS
############################################################################################################
#All available IDs
opx_ids = [x.replace('.tif','') for x in os.listdir(feature_path) if x != '.DS_Store'] #210 , excluded 7 fine-tune cases
opx_ids.sort()

#Check cancer detection
all_tile_info_list = list()
for pt in opx_ids:
    cur_tile_info = pd.read_hdf(feature_path + pt + '/features/' + 'features_alltiles_' +  feature_extraction_method + '.h5', key='tile_info')
    cur_tumor_info_df = pd.read_csv(os.path.join(tumor_info_path, pt, "ft_model/", pt + "_TILE_TUMOR_PERC.csv"))
    cur_tile_info = cur_tile_info.merge(cur_tumor_info_df, on = ['SAMPLE_ID', 'MAG_EXTRACT', 'SAVE_IMAGE_SIZE', 'PIXEL_OVERLAP',
                                                                 'LIMIT_BOUNDS', 'TILE_XY_INDEXES', 'TILE_COOR_ATLV0', 'WHITE_SPACE',
                                                                 'TISSUE_COVERAGE'])
    all_tile_info_list.append(cur_tile_info)

all_tile_info = pd.concat(all_tile_info_list)

all_tile_info_thres = all_tile_info.loc[all_tile_info['TUMOR_PIXEL_PERC'] >= TUMOR_FRAC_THRES]

nocancer_ids = [x for x in opx_ids if x not in list(set(all_tile_info_thres['SAMPLE_ID']))]
print("No Cancer IDs",nocancer_ids)

#Excluded 2 colon cases: OPX_085, OPX_182
toexclude_ids = nocancer_ids + ['OPX_085','OPX_182']  #25

#Exclude ids in ft_train or processed
selected_ids = [x for x in opx_ids if x not in toexclude_ids] #199
print(len(selected_ids))
# Out:
# No Cancer IDs ['TMA97A-1-11', 'TMA97A-1-12', 'TMA97A-1-13', 'TMA97A-1-3', 'TMA97A-1-6', 'TMA97A-2-2', 'TMA97A-2-3', 'TMA97A-2-5', 'TMA97A-3-10', 'TMA97A-4-12', 'TMA97A-4-7', 'TMA97A-5-10', 'TMA97A-5-13', 'TMA97A-5-3', 'TMA97A-5-7', 'TMA97A-6-1', 'TMA97A-6-3', 'TMA97A-6-4', 'TMA97A-6-6', 'TMA97A-7-13', 'TMA97A-7-2', 'TMA97A-7-8', 'TMA97A-8-11', 'TMA97A-8-4', 'TMA97B-1-12', 'TMA97B-1-13', 'TMA97B-1-2', 'TMA97B-1-9', 'TMA97B-2-1', 'TMA97B-3-13', 'TMA97B-3-2', 'TMA97B-3-3', 'TMA97B-3-9', 'TMA97B-4-10', 'TMA97B-4-11', 'TMA97B-5-4', 'TMA97B-6-11', 'TMA97B-6-6', 'TMA97B-6-7', 'TMA97B-7-5', 'TMA97B-7-6', 'TMA97B-7-9', 'TMA97B-8-10', 'TMA97B-8-11', 'TMA97B-8-13', 'TMA97B-9-11', 'TMA97B-9-12', 'TMA97B-9-2', 'TMA97B-9-9', 'TMA97C-1-10', 'TMA97C-1-11', 'TMA97C-1-12', 'TMA97C-1-13', 'TMA97C-1-8', 'TMA97C-1-9', 'TMA97C-2-1', 'TMA97C-2-10', 'TMA97C-2-13', 'TMA97C-2-2', 'TMA97C-2-3', 'TMA97C-2-5', 'TMA97C-2-6', 'TMA97C-2-8', 'TMA97C-2-9', 'TMA97C-3-1', 'TMA97C-3-12', 'TMA97C-3-13', 'TMA97C-3-2', 'TMA97C-3-3', 'TMA97C-3-4', 'TMA97C-3-6', 'TMA97C-3-8', 'TMA97C-4-1', 'TMA97C-4-10', 'TMA97C-4-11', 'TMA97C-4-2', 'TMA97C-4-5', 'TMA97C-4-7', 'TMA97C-5-7', 'TMA97C-6-1', 'TMA97C-6-10', 'TMA97C-6-11', 'TMA97C-6-12', 'TMA97C-6-5', 'TMA97C-6-7', 'TMA97C-7-1', 'TMA97C-8-12', 'TMA97C-8-13', 'TMA97C-8-6', 'TMA97C-9-1', 'TMA97C-9-10', 'TMA97C-9-11', 'TMA97C-9-12', 'TMA97C-9-3', 'TMA97C-9-5', 'TMA97D-1-1', 'TMA97D-1-11', 'TMA97D-1-14', 'TMA97D-1-4', 'TMA97D-2-14', 'TMA97D-2-3', 'TMA97D-2-4', 'TMA97D-2-5', 'TMA97D-2-6', 'TMA97D-2-8', 'TMA97D-2-9', 'TMA97D-3-1', 'TMA97D-3-10', 'TMA97D-3-11', 'TMA97D-3-14', 'TMA97D-3-2', 'TMA97D-3-3', 'TMA97D-3-4', 'TMA97D-3-5', 'TMA97D-3-6', 'TMA97D-3-7', 'TMA97D-3-9', 'TMA97D-4-1', 'TMA97D-4-12', 'TMA97D-4-13', 'TMA97D-4-14', 'TMA97D-4-3', 'TMA97D-4-4', 'TMA97D-4-5', 'TMA97D-4-6', 'TMA97D-4-8', 'TMA97D-5-7', 'TMA97D-5-8', 'TMA97D-5-9', 'TMA97D-6-5', 'TMA97D-6-6', 'TMA97D-6-9', 'TMA97D-7-12', 'TMA97D-7-13', 'TMA97D-7-5', 'TMA97D-7-6', 'TMA97F-1-12', 'TMA97F-1-13', 'TMA97F-1-14', 'TMA97F-1-3', 'TMA97F-1-9', 'TMA97F-2-1', 'TMA97F-2-10', 'TMA97F-2-11', 'TMA97F-2-12', 'TMA97F-2-13', 'TMA97F-2-3', 'TMA97F-2-4', 'TMA97F-2-5', 'TMA97F-2-6', 'TMA97F-3-11', 'TMA97F-3-14', 'TMA97F-3-7', 'TMA97F-3-8', 'TMA97F-3-9', 'TMA97F-4-1', 'TMA97F-4-10', 'TMA97F-4-11', 'TMA97F-4-12', 'TMA97F-4-13', 'TMA97F-4-9', 'TMA97F-5-10', 'TMA97F-5-11', 'TMA97F-5-12', 'TMA97F-5-4', 'TMA97F-5-6', 'TMA97F-5-7', 'TMA97F-6-1', 'TMA97F-6-12', 'TMA97F-6-13', 'TMA97F-6-3', 'TMA97F-6-4', 'TMA97F-7-1', 'TMA97G-1-14', 'TMA97G-2-1', 'TMA97G-2-10', 'TMA97G-2-12', 'TMA97G-2-13', 'TMA97G-2-14', 'TMA97G-2-4', 'TMA97G-2-5', 'TMA97G-2-6', 'TMA97G-3-1', 'TMA97G-3-14', 'TMA97G-3-3', 'TMA97G-3-4', 'TMA97G-4-13', 'TMA97G-5-13', 'TMA97G-6-6', 'TMA97G-7-1', 'TMA97G-7-3', 'TMA97G-7-4', 'TMA97G-7-5', 'TMA97H-1-1', 'TMA97H-1-14', 'TMA97H-1-2', 'TMA97H-2-11', 'TMA97H-2-14', 'TMA97H-2-3', 'TMA97H-2-6', 'TMA97H-2-8', 'TMA97H-2-9', 'TMA97H-3-1', 'TMA97H-3-10', 'TMA97H-3-14', 'TMA97H-3-3', 'TMA97H-3-5', 'TMA97H-4-1', 'TMA97H-4-5', 'TMA97H-4-6', 'TMA97H-4-7', 'TMA97H-4-8', 'TMA97H-4-9', 'TMA97H-5-3', 'TMA97H-5-4', 'TMA97H-5-7', 'TMA97H-6-10', 'TMA97H-6-11', 'TMA97H-6-13', 'TMA97H-6-5', 'TMA97H-6-8', 'TMA97H-7-1', 'TMA97H-7-10', 'TMA97H-7-11', 'TMA97H-7-12', 'TMA97H-7-13', 'TMA97H-7-2', 'TMA97H-7-3', 'TMA97H-7-5', 'TMA97H-7-6', 'TMA97H-8-1', 'TMA97H-8-10', 'TMA97H-8-11', 'TMA97H-8-12', 'TMA97H-8-13', 'TMA97H-8-14', 'TMA97H-8-2', 'TMA97H-8-3', 'TMA97H-8-4', 'TMA97H-8-5', 'TMA97H-8-6', 'TMA97I-1-1', 'TMA97I-1-11', 'TMA97I-1-12', 'TMA97I-1-13', 'TMA97I-1-2', 'TMA97I-1-6', 'TMA97I-1-8', 'TMA97I-1-9', 'TMA97I-2-1', 'TMA97I-2-10', 'TMA97I-2-2', 'TMA97I-2-5', 'TMA97I-2-6', 'TMA97I-2-8', 'TMA97I-2-9', 'TMA97I-3-10', 'TMA97I-3-11', 'TMA97I-3-6', 'TMA97I-3-9', 'TMA97I-4-10', 'TMA97I-4-11', 'TMA97I-4-12', 'TMA97I-4-13', 'TMA97I-4-2', 'TMA97I-4-4', 'TMA97I-4-7', 'TMA97I-4-8', 'TMA97I-4-9', 'TMA97I-5-1', 'TMA97I-5-10', 'TMA97I-5-11', 'TMA97I-5-12', 'TMA97I-5-13', 'TMA97I-5-2', 'TMA97I-5-3', 'TMA97I-5-4', ' ...
# 378

# %%
############################################################################################################
#Get features and labels
#NOTE: OPX_005 has no tumor tiles in fold0 train, so excluded in this step
############################################################################################################
feature_name = 'features_alltiles_' +  feature_extraction_method 
feature, label, info, tf_info, select_val_ids = get_feature_label_array_dynamic(feature_path,
                                                                                tumor_info_path,
                                                                                feature_name, 
                                                                                selected_ids, 
                                                                                SELECTED_LABEL,
                                                                                SELECTED_FEATURE,
                                                                                tumor_fraction_thres = TUMOR_FRAC_THRES)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       1 ############################################################################################################
#       2 #Get features and labels
#       3 #NOTE: OPX_005 has no tumor tiles in fold0 train, so excluded in this step
#       4 ############################################################################################################
#       5 feature_name = 'features_alltiles_' +  feature_extraction_method
# ----> 6 feature, label, info, tf_info, select_val_ids = get_feature_label_array_dynamic(feature_path,
#       7                                                                                 tumor_info_path,
#       8                                                                                 feature_name,
#       9                                                                                 selected_ids,
#      10                                                                                 SELECTED_LABEL,
#      11                                                                                 SELECTED_FEATURE,
#      12                                                                                 tumor_fraction_thres = TUMOR_FRAC_THRES)
#
# File /fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/code_s/cancer_detection_final/../Utils/train_utils.py:180, in get_feature_label_array_dynamic(feature_path, tumor_info_path, feature_name, selected_ids, selected_labels, selected_feature, tumor_fraction_thres)
#     176 cur_selected_df = cur_selected_df.reset_index(drop = True)
#     178 if cur_selected_df is not None :
#     179     #Extract feature, label and tumor info
# --> 180     cur_feature, cur_label, cur_info, cur_tf_info =  extract_feature_label_tumorinfo_np(cur_selected_df, selected_feature, selected_labels)
#     181     feature_list.append(cur_feature)
#     182     label_list.append(cur_label)
#
# File /fh/fast/etzioni_r/Lucas/mh_proj/mutation_pred/code_s/cancer_detection_final/../Utils/train_utils.py:139, in extract_feature_label_tumorinfo_np(selected_df, selected_feature, selected_labels)
#     136 def extract_feature_label_tumorinfo_np(selected_df, selected_feature, selected_labels):
#     137     #Extract feature, label and tumor info
#     138     feature_np = selected_df[selected_feature].values #np array
# --> 139     label_np   = selected_df[selected_labels].drop_duplicates().values.astype('float32') #numpy array
#     140     info_np    = selected_df[['SAMPLE_ID', 'MAG_EXTRACT', 'SAVE_IMAGE_SIZE', 'PIXEL_OVERLAP', 'LIMIT_BOUNDS',
#     141                                'TILE_XY_INDEXES', 'TILE_COOR_ATLV0', 'WHITE_SPACE', 'TISSUE_COVERAGE',
#     142                                'Bx Type', 'Anatomic site', 'Notes', 'SITE_LOCAL', 'pred_map_location', 'TUMOR_PIXEL_PERC']]
#     143     tf_info_np = selected_df['TUMOR_PIXEL_PERC'].values
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['MMR (MSH2, MSH6, PMS2, MLH1, MSH3, MLH3, EPCAM)2', 'TMB_HIGHorINTERMEDITATE', 'MSI_POS'] not in index"

# %%
torch.save(feature,   outdir + '/OPX_feature.pth')
torch.save(label,   outdir + '/OPX_label.pth')
torch.save(info,   outdir + '/OPX_info.pth')
torch.save(tf_info,   outdir + '/OPX_tfinfo.pth')
torch.save(select_val_ids,   outdir + '/OPX_ids.pth')

# %%
#TODO: Double check this two, why not match
print(all_tile_info_thres.shape) #930297
check = np.concatenate(info) #927717
check.shape

# %%
############################################################################################################
#Count Distribution
############################################################################################################
counts = count_label(label, SELECTED_LABEL, "OPX")
print(counts)
counts.to_csv(outdir + '/OPX_counts.csv')

# %%
#Get model ready data
data = ModelReadyData_diffdim(feature,label,tf_info,
                                  include_tumor_fraction = False, 
                                  include_cluster = False, 
                                  feature_name =feature_extraction_method)
torch.save(data, outdir + '/OPX_data.pth')

# %%
data[0][0].shape
